# %%
from dataloaders import create_loaders
root = r"./../../data/preprocessed"
train_loader, val_loader, test_loader = create_loaders(root, 16, 2)
# Out:
#  DATA LOADED:
#   Train: 152352 samples
#   Val:   19044 samples
#   Test:  19044 samples
# (<torch.utils.data.dataloader.DataLoader at 0x745a3767ba90>,
# ...
#  <torch.utils.data.dataloader.DataLoader at 0x745a37682f50>)
